# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec
from matplotlib import cm
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib

# %%
ds = xr.open_dataset('cs2_landy_data.nc')

# %% [markdown]
# ### Pan-Arctic

# %%
fig, axes = plt.subplots(nrows = 2, figsize=(10,5))

axes[0].plot(ds.time, ds.SIA/1e12) # millions of km^2
axes[0].plot(ann_SIA.year[1:], ann_SIA[1:]/1e12)
axes[0].set_ylim([0, 20])
axes[0].set_xticks([])
axes[0].set_ylabel('area ($mil. km^2$)', fontweight='bold', color='grey')

axes[1].plot(ds.time, ds.SIV/1e12) # thousands of km^3
axes[1].plot(ann_SIV.year[1:], ann_SIV[1:]/1e12)
axes[1].set_ylim([0, 20])
axes[1].set_ylabel('volume ($thous. km^3$)', fontweight='bold', color='grey')
axes[1].set_xlabel('time', fontweight='bold', color='grey')
# Out:
# Text(0.5, 0, 'time')

# %%
ann_SIA = ds.SIA.groupby('time.year').mean(dim='time')
ann_SIV = ds.SIV.groupby('time.year').mean(dim='time')

# %%
year_time = [datetime.datetime(i,6,15) for i in range(2010,2021)]

# %%
import datetime

# %%
ann_SIA['year'] = year_time
ann_SIV['year'] = year_time
